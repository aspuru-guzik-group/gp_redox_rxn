# %%
from IPython.display import Image, SVG
from rdkit import Chem
import json
from rdkit.Chem.Draw import IPythonConsole, ReactionToImage
from rdkit.Chem import AllChem,Draw,Descriptors
import copy
import pandas as pd
import re
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/haniu/anaconda2/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#path_name = '/Users/ajinich/Dropbox (Aspuru-Guzik Lab)/Quantum/redox/data_for_Ben/10C_Redox.csv'
path_name = '~/Dropbox/Quantum/redox/data_for_Ben/10C_Redox.csv'
redox_rxns = pd.read_csv(path_name)

# %%
kegg_rxns = pd.read_csv('KEGG_ALL.csv', sep = '\t', engine = 'python')

# %%
with open('Kegg_Canonical_Final.json', 'r') as fp:
        Kegg_smiles_dict = json.load(fp)

# %%
Kegg_smiles = []
for x in Kegg_smiles_dict:
    Kegg_smiles.append(Kegg_smiles_dict[x])

# %%
Kegg_reaction = list(kegg_rxns.EQUATION.values)

# %%
kegg_rxns
# Out:
#                                              DEFINITION  \
# 0        Polyphosphate + n H2O <=> (n+1) Oligophosphate
# 1     16 ATP + 16 H2O + 8 Reduced ferredoxin <=> 8 e...
# 2                Diphosphate + H2O <=> 2 Orthophosphate
# 3        Urea-1-carboxylate + H2O <=> 2 CO2 + 2 Ammonia
# 4                   2-Acetolactate + CO2 <=> 2 Pyruvate
# 5                           Parapyruvate <=> 2 Pyruvate
# 6                2 Hydrogen peroxide <=> Oxygen + 2 H2O
# 7           alpha,alpha-Trehalose + H2O <=> 2 D-Glucose
# 8     2 Manganese(2+) + Hydrogen peroxide + 2 H+ <=>...
# 9     2 GTP <=> Diphosphate + P1,P4-Bis(5'-guanosyl)...
# 10     2 Glyoxylate <=> 2-Hydroxy-3-oxopropanoate + CO2
# 11    Pyruvate + Thiamin diphosphate <=> 2-(alpha-Hy...
# 12    2 Sucrose <=> D-Glucose + 1F-beta-D-Fructosyls...
# 13    Hydrogen peroxide + 2 Ferrocytochrome c <=> 2 ...
# 14        2 Putrescine <=> sym-Homospermidine + Ammonia
# 15    2 Reduced ferredoxin + 2 H+ <=> Hydrogen + 2 O...
# 16    2 L-Glutamate + 2 Oxidized ferredoxin <=> L-Gl...
# 17        Chitobiose + H2O <=> 2 N-Acetyl-D-glucosamine
# 18    2 Hydroxylamine + 2 NAD+ <=> Hyponitrite + 2 N...
# 19    D-Ribulose 1,5-bisphosphate + CO2 + H2O <=> 2 ...
# 20    Ethylnitronate + Oxygen + Reduced FMN <=> Acet...
# 21                Cellobiose + H2O <=> 2 beta-D-Glucose
# 22                           Benzoin <=> 2 Benzaldehyde
# 23                  Maltose + H2O <=> 2 alpha-D-Glucose
# 24    2 Thiosulfate + 2 Ferricytochrome c <=> Tetrat...
# 25    Oxygen + 2 L-Tyrosine <=> 2 3,4-Dihydroxy-L-ph...
# 26                 beta-Carotene + Oxygen <=> 2 Retinal
# 27    Thiamine + Oxygen <=> Hydrogen peroxide + Thia...
# 28    Cyclobutadipyrimidine <=> 2 Pyrimidine 5'-deox...
# 29      2 5-Aminolevulinate <=> Porphobilinogen + 2 H2O
# ...                                                 ...
# 8380  Anthraniloyl-CoA + Methanol <=> CoA + O-Methyl...
# 8381  6-Deoxocastasterone + 3 Oxygen + 3 Reduced fla...
# 8382  6-Deoxotyphasterol + 3 Oxygen + 3 Reduced flav...
# 8383  6-Deoxoteasterone + 3 Oxygen + 3 Reduced flavo...
# 8384  N-Acetylaspartylglutamate + H2O <=> N-Acetyl-L...
# 8385  N-Acetylaspartylglutamylglutamate + H2O <=> N-...
# 8386          L-Fucono-1,5-lactone + H2O <=> L-Fuconate
# 8387  2-Dehydro-3-deoxy-L-fuconate + NAD+ <=> 2,4-Di...
# 8388  2,4-Diketo-3-deoxy-L-fuconate + H2O <=> (S)-La...
# 8389  20,21-Diprenylterpendole J + 3 Oxygen + 3 NADP...
# 8390  ATP + N-Acetylaspartylglutamate + L-Glutamate ...
# 8391  20,21-Diprenylterpendole C + 3 Oxygen + 3 NADP...
# 8392  6-Amino-6-deoxyfutalosine + H2O <=> Futalosine...
# 8393  6-Oxocyclohex-1-ene-1-carbonyl-CoA + H2O <=> 2...
# 8394         (S)-2-Phenyloxirane <=> Phenylacetaldehyde
# 8395  Kanosamine 6-phosphate + 2-Oxoglutarate <=> 3-...
# 8396  L-Lysine + 8-Amino-7-oxononanoate <=> L-2-Amin...
# 8397  Hexadecanoyl-[acp] + CoA <=> Palmitoyl-CoA + A...
# 8398  5-O-Caffeoylshikimic acid + H2O <=> Caffeate +...
# 8399  Propane + NADH + H+ + Oxygen <=> Propan-2-ol +...
# 8400         Propan-2-ol + NAD+ <=> Acetone + NADH + H+
# 8401  Acetone + NADPH + H+ + Oxygen <=> Methyl aceta...
# 8402        Methyl acetate + H2O <=> Acetate + Methanol
# 8403  2'-(5-Triphosphoribosyl)-3'-dephospho-CoA + Ap...
# 8404  Acetyl-CoA + Malonyl-[acyl-carrier protein] <=...
# 8405  Geranylgeranyl diphosphate + Homogentisate <=>...
# 8406  S-Adenosyl-L-methionine + 2-Methyl-6-solanyl-1...
# 8407  S-Adenosyl-L-methionine + 6-Geranylgeranyl-2-m...
# 8408  2-Methyl-4-amino-5-hydroxymethylpyrimidine dip...
# 8409  Primary alcohol + 2 Ferricytochrome cL <=> Ald...
#
#                          EC_CLASS  \
# 0                        3.6.1.10
# 1                        1.18.6.1
# 2                         3.6.1.1
# 3                        3.5.1.54
# 4                         2.2.1.6
# 5                        4.1.3.17
# 6            1.11.1.6 / 1.11.1.21
# 7                        3.2.1.28
# 8                       1.11.1.13
# 9                        2.7.7.45
# 10                       4.1.1.47
# 11    1.2.4.1 / 2.2.1.6 / 4.1.1.1
# 12                       2.4.1.99
# 13                       1.11.1.5
# 14                       2.5.1.44
# 15           1.12.7.2 / 1.12.99.-
# 16                        1.4.7.1
# 17                       3.2.1.52
# 18                        1.7.1.5
# 19                       4.1.1.39
# 20                     1.13.12.16
# 21                       3.2.1.21
# 22                       4.1.2.38
# 23                       3.2.1.20
# 24                        1.8.2.2
# 25           1.10.3.1 / 1.14.18.1
# 26        1.13.11.63 / 1.14.99.36
# 27                       1.1.3.23
# 28                       4.1.99.3
# 29                       4.2.1.24
# ...                           ...
# 8380                    2.3.1.232
# 8381                     1.14.-.-
# 8382                     1.14.-.-
# 8383                     1.14.-.-
# 8384                    3.4.17.21
# 8385                    3.4.17.21
# 8386                      3.1.1.-
# 8387                      1.1.1.-
# 8388                      3.7.1.-
# 8389                    1.14.13.-
# 8390                     6.3.2.42
# 8391                    1.14.13.-
# 8392                     3.5.4.40
# 8393                     3.7.1.21
# 8394                     5.3.99.7
# 8395                    2.6.1.104
# 8396                    2.6.1.105
# 8397                     2.3.1.86
# 8398                      3.1.1.-
# 8399                    1.14.13.-
# 8400                      1.1.1.-
# 8401                    1.14.13.-
# 8402                      3.1.1.-
# 8403          2.7.7.61 / 2.7.7.66
# 8404                    2.3.1.180
# 8405                    2.5.1.116
# 8406                    2.1.1.295
# 8407                    2.1.1.295
# 8408                      2.5.1.3
# 8409                      1.1.2.7
#
#                                                EQUATION KEGG_ID  \
# 0                    C00404 + n C00001 <=> (n+1) C02174  R00001
# 1     16 C00002 + 16 C00001 + 8 C00138 <=> 8 C05359 ...  R00002
# 2                          C00013 + C00001 <=> 2 C00009  R00004
# 3               C01010 + C00001 <=> 2 C00011 + 2 C00014  R00005
# 4                          C00900 + C00011 <=> 2 C00022  R00006
# 5                                   C06033 <=> 2 C00022  R00008
# 6                        2 C00027 <=> C00007 + 2 C00001  R00009
# 7                          C01083 + C00001 <=> 2 C00031  R00010
# 8     2 C19610 + C00027 + 2 C00080 <=> 2 C19611 + 2 ...  R00011
# 9                          2 C00044 <=> C00013 + C01261  R00012
# 10                         2 C00048 <=> C01146 + C00011  R00013
# 11                  C00022 + C00068 <=> C05125 + C00011  R00014
# 12                         2 C00089 <=> C00031 + C03661  R00015
# 13            C00027 + 2 C00126 <=> 2 C00125 + 2 C00001  R00017
# 14                         2 C00134 <=> C06366 + C00014  R00018
# 15            2 C00138 + 2 C00080 <=> C00282 + 2 C00139  R00019
# 16    2 C00025 + 2 C00139 <=> C00064 + C00026 + 2 C0...  R00021
# 17                         C01674 + C00001 <=> 2 C00140  R00022
# 18    2 C00192 + 2 C00003 <=> C01818 + 2 C00004 + 2 ...  R00023
# 19                C01182 + C00011 + C00001 <=> 2 C00197  R00024
# 20    C18091 + C00007 + C01847 <=> C00084 + C00088 +...  R00025
# 21                         C00185 + C00001 <=> 2 C00221  R00026
# 22                                  C01408 <=> 2 C00261  R00027
# 23                         C00208 + C00001 <=> 2 C00267  R00028
# 24            2 C00320 + 2 C00125 <=> C02084 + 2 C00126  R00029
# 25                       C00007 + 2 C00082 <=> 2 C00355  R00031
# 26                         C02094 + C00007 <=> 2 C00376  R00032
# 27                  C00378 + C00007 <=> C00027 + C05856  R00033
# 28                                  C03103 <=> 2 C08249  R00034
# 29                       2 C00430 <=> C00931 + 2 C00001  R00036
# ...                                                 ...     ...
# 8380                C02247 + C00132 <=> C00010 + C20634  R10681
# 8381  C15802 + 3 C00007 + 3 C03024 <=> C08814 + 4 C0...  R10682
# 8382  C15801 + 3 C00007 + 3 C03024 <=> C17735 + 4 C0...  R10683
# 8383  C15799 + 3 C00007 + 3 C03024 <=> C17733 + 4 C0...  R10684
# 8384                C12270 + C00001 <=> C01042 + C00025  R10687
# 8385                C20776 + C00001 <=> C12270 + C00025  R10688
# 8386                         C18028 + C00001 <=> C01720  R10689
# 8387       C03827 + C00003 <=> C20781 + C00004 + C00080  R10690
# 8388                C20781 + C00001 <=> C00186 + C00022  R10691
# 8389  C20594 + 3 C00007 + 3 C00005 + 3 C00080 <=> C2...  R10692
# 8390  C00002 + C12270 + C00025 <=> C00008 + C00009 +...  R10693
# 8391  C20595 + 3 C00007 + 3 C00005 + 3 C00080 <=> C2...  R10694
# 8392                C20773 + C00001 <=> C16999 + C00014  R10695
# 8393                         C09821 + C00001 <=> C09825  R10696
# 8394                                  C20782 <=> C00601  R10697
# 8395                C12213 + C00026 <=> C20668 + C00025  R10698
# 8396                C00047 + C01092 <=> C04076 + C01037  R10699
# 8397                C05764 + C00010 <=> C00154 + C00229  R10700
# 8398                C10434 + C00001 <=> C01197 + C00493  R10701
# 8399  C20783 + C00004 + C00080 + C00007 <=> C01845 +...  R10702
# 8400       C01845 + C00003 <=> C00207 + C00004 + C00080  R10703
# 8401  C00207 + C00005 + C00080 + C00007 <=> C17530 +...  R10704
# 8402                C17530 + C00001 <=> C00033 + C00132  R10705
# 8403                C19771 + C03688 <=> C00229 + C00013  R10706
# 8404       C00024 + C01209 <=> C05744 + C00010 + C00011  R10707
# 8405       C00353 + C00544 <=> C00013 + C20737 + C00011  R10708
# 8406                C00019 + C17570 <=> C00021 + C16695  R10709
# 8407                C00019 + C20737 <=> C00021 + C20738  R10710
# 8408       C04752 + C20247 <=> C01081 + C00013 + C00011  R10712
# 8409  C00226 + 2 C18233 <=> C00071 + 2 C18234 + 2 C0...  R10713
#
#                                                    NAME
# 0                    polyphosphate polyphosphohydrolase
# 1     Reduced ferredoxin:dinitrogen oxidoreductase (...
# 2                         diphosphate phosphohydrolase;
# 3                     urea-1-carboxylate amidohydrolase
# 4     pyruvate:pyruvate acetaldehydetransferase (dec...
# 5     4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lya...
# 6     hydrogen-peroxide:hydrogen-peroxide oxidoreduc...
# 7                  alpha,alpha-trehalose glucohydrolase
# 8               Mn(II):hydrogen-peroxide oxidoreductase
# 9                           GTP:GTP guanylyltransferase
# 10    glyoxylate carboxy-lyase (dimerizing; tartrona...
# 11    pyruvate:thiamin diphosphate acetaldehydetrans...
# 12      sucrose:sucrose 1'-beta-D-fructosyltransferase;
# 13    ferrocytochrome-c:hydrogen-peroxide oxidoreduc...
# 14    putrescine:putrescine 4-aminobutyltransferase ...
# 15                  hydrogen:ferredoxin oxidoreductase;
# 16    L-glutamate:ferredoxin oxidoreductase (transam...
# 17              chitobiose N-acetylglucosaminohydrolase
# 18                   hydroxylamine:NAD+ oxidoreductase;
# 19    3-phospho-D-glycerate carboxy-lyase (dimerizin...
# 20    ethylnitronate:oxygen 2-oxidoreductase (nitrit...
# 21                            cellobiose glucohydrolase
# 22    2-hydroxy-1,2-diphenylethanone benzaldehyde-ly...
# 23                               maltose glucohydrolase
# 24         thiosulfate:ferricytochrome-c oxidoreductase
# 25                1,2-benzenediol:oxygen oxidoreductase
# 26    beta-carotene:oxygen 15,15'-oxidoreductase (bo...
# 27                     thiamine:oxygen 5-oxidoreductase
# 28      Cyclobutadipyrimidine (in DNA) pyrimidine-lyase
# 29    5-aminolevulinate hydro-lyase (adding 5-aminol...
# ...                                                 ...
# 8380  anthraniloyl-CoA:methanol O-anthraniloyltransf...
# 8381                                                NaN
# 8382                                                NaN
# 8383                                                NaN
# 8384                                                NaN
# 8385                                                NaN
# 8386                                                NaN
# 8387                                                NaN
# 8388                                                NaN
# 8389                                                NaN
# 8390  N-acetyl-L-aspartyl-L-glutamate:L-glutamate li...
# 8391                                                NaN
# 8392                6-amino-6-deoxyfutalosine deaminase
# 8393  6-oxocyclohex-1-ene-1-carbonyl-CoA hydro-lyase...
# 8394         styrene-oxide isomerase (epoxide-cleaving)
# 8395  kanosamine-6-phosphate:2-oxoglutarate aminotra...
# 8396   L-lysine:8-amino-7-oxononanoate aminotransferase
# 8397         palmitoyl-[acp]:CoA S-palmitoyltransferase
# 8398                                                NaN
# 8399                 propane,NADH:oxygen oxidoreductase
# 8400                    propan-2-ol:NAD+ oxidoreductase
# 8401                acetone,NADPH:oxygen oxidoreductase
# 8402                     methyl-acetate acetylhydrolase
# 8403  2'-(5-triphosphoribosyl)-3'-dephospho-CoA:apo-...
# 8404  acetyl-CoA:malonyl-[acyl-carrier protein] C-ac...
# 8405  geranylgeranyl-diphosphate:homogentisate geran...
# 8406  S-adenosyl-L-methionine:2-methyl-6-solanyl-1,4...
# 8407  S-adenosyl-L-methionine:6-geranylgeranyl-2-met...
# 8408  2-methyl-4-amino-5-hydroxymethylpyrimidine-dip...
# 8409       primary alcohol:cytochrome cL oxidoreductase
#
# [8410 rows x 5 columns]

# %% [markdown]
# # Functions

# %%
def count_carbons(x):
    smiles = x.Reaction
    
    metabolite = smiles.split('>>')[1]
    
    new_smiles = metabolite.replace('Cl', '')
    numC = new_smiles.count('C') + new_smiles.count('c')
    
    return numC

def same_numC(x):
    reaction = x.Reaction
    
    new_reaction = reaction.replace('Cl', '')
    
    sub = new_reaction.split('>>')[0]
    prod = new_reaction.split('>>')[1]
    
    sub_numC = sub.count('C') + sub.count('c')
    prod_numC = prod.count('C') + prod.count('c')
    
    if sub_numC != prod_numC:
        return False
    
    return True

def same_numN(x):
    reaction = x.Reaction
    
    sub = reaction.split('>>')[0]
    prod = reaction.split('>>')[1]
    
    sub_numN = sub.count('N')
    prod_numN = prod.count('N')
    
    if sub_numN != prod_numN:
        return False
    
    return True

def SmilesToKegg(x):
    rxn = x.Reaction
    
    sub = rxn.split('>>')[0]
    prod = rxn.split('>>')[1]

    if sub in Kegg_smiles and prod in Kegg_smiles:
        for key in Kegg_smiles_dict:
            if Kegg_smiles_dict[key] == sub:
                kegg_sub = key
            if Kegg_smiles_dict[key] == prod:
                kegg_prod = key

        kegg_rxn = kegg_sub + ' = ' + kegg_prod

        return kegg_rxn
    
    return 'None'

def CompareToKEGG(x):
    rxn = x.Kegg_ID
    
    if rxn != 'None':
        sub = rxn.split(' = ')[0]
        prod = rxn.split(' = ')[1]

        for reaction in Kegg_reaction:
            Kegg_sub = reaction.split('<=>')[0]
            Kegg_prod = reaction.split('<=>')[1]

            #print Kegg_sub, Kegg_prod
            if sub in Kegg_sub and prod in Kegg_prod:
                return reaction

    return False

# %% [markdown]
# # Compare Metabolites to Kegg Metabolites

# %%
redox_rxns['Same_NumN'] = redox_rxns.apply(same_numN, 1)

# %%
redox_rxns = redox_rxns[redox_rxns.Same_NumN == True]

# %%
redox_rxns['numC'] = redox_rxns.apply(count_carbons, 1)

# %%
redox_rxns_2C = redox_rxns[redox_rxns.numC == 2]
redox_rxns_3C = redox_rxns[redox_rxns.numC == 3]
redox_rxns_4C = redox_rxns[redox_rxns.numC == 4]

# %%
redox_rxns_2C.head()
# Out:
#      Reaction Same_NumN  numC
# 0     CCO>>CC      True     2
# 7   CSCO>>CSC      True     2
# 8   OCCF>>CCF      True     2
# 10  NCCO>>CCN      True     2
# 11  COCO>>COC      True     2

# %%
del redox_rxns_2C['Same_NumN']
del redox_rxns_2C['numC']
del redox_rxns_3C['Same_NumN']
del redox_rxns_3C['numC']
del redox_rxns_4C['Same_NumN']
del redox_rxns_4C['numC']

# %%
redox_rxns_2C.to_csv('2C_redox_rxns.csv', index = False)
redox_rxns_3C.to_csv('3C_redox_rxns.csv', index = False)
redox_rxns_4C.to_csv('4C_redox_rxns.csv', index = False)

# %%
redox_list = pd.DataFrame(redox_rxns.Reaction.values, columns = ['Reaction'])

# %%
rxn_list_2C = list(redox_rxns_2C.Reaction.values)
rxn_list_3C = list(redox_rxns_3C.Reaction.values)
rxn_list_4C = list(redox_rxns_4C.Reaction.values)

# %%
redox_rxns_4C['Kegg_ID'] = redox_rxns_4C.apply(SmilesToKegg, 1)
# Out:
# /home/haniu/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
redox_rxns_4C['KEGG_Rxn'] = redox_rxns_4C.apply(CompareToKEGG, 1)
# Out:
# /home/haniu/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
redox_rxns_4C[redox_rxns_4C.KEGG_Rxn != False]
# Out:
#                                         Reaction          Kegg_ID  \
# 81                                 CCCC=O>>CCCCO  C01412 = C06142
# 6799               CC(=O)C(C)=O>>CC(=O)[C@H](C)O  C00741 = C01769
# 34444       CC(C(=O)O)C(=O)O>>C[C@@H](C=O)C(=O)O  C02170 = C06002
# 40835      O=C(O)C[C@H](O)C(=O)O>>O=C(O)CCC(=O)O  C00149 = C00042
# 47229     O=C(O)C[C@@H](O)C(=O)O>>O=C(O)CCC(=O)O  C00497 = C00042
# 70278  O=C(O)CC(=O)C(=O)O>>O=C(O)C[C@H](O)C(=O)O  C00036 = C00149
#
#                                            KEGG_Rxn
# 81     C01412 + C00004 + C00080 <=> C06142 + C00003
# 6799   C00741 + C00004 + C00080 <=> C01769 + C00003
# 34444  C02170 + C00027 <=> C06002 + C00007 + C00001
# 40835           C00091 + C00149 <=> C00042 + C04348
# 47229           C00091 + C00497 <=> C00042 + C20747
# 70278           C00186 + C00036 <=> C00149 + C00022

# %%
for rxn in rxn_list_4C[2000:2100]:
    print rxn
    display(AllChem.ReactionFromSmarts(str(rxn)))
# Out:
# O=CC(O)C(O)C(O)(P(=O)(O)O)P(=O)(O)O>>O=CCC(O)C(O)(P(=O)(O)O)P(=O)(O)O
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-56cd8f4a3bc8> in <module>()
#       1 for rxn in rxn_list_4C[2000:2100]:
#       2     print rxn
# ----> 3     display(AllChem.ReactionFromSmarts(str(rxn)))
#
# NameError: name 'display' is not defined

# %%
display(AllChem.ReactionFromSmarts('O=C(O)CC(=O)C(=O)O>>O=C(O)C[C@H](O)C(=O)O'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-3e1929725edb> in <module>()
# ----> 1 display(AllChem.ReactionFromSmarts('O=C(O)CC(=O)C(=O)O>>O=C(O)C[C@H](O)C(=O)O'))
#
# NameError: name 'display' is not defined
